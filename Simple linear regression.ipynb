# %%
#simple linear regression
# only one dep and only one ind var

# %%
# importing the libraries
import os,sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from scipy import stats

# %%
# import file
df=pd.read_csv('placement.csv')
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
#to check the relationship
plt.scatter(df['cgpa'],df['package'])

# %%
#dividing the dataset into dep and ind var
x=df['cgpa']
#x=df.iloc[:,0]

# %%
x.head()
# Out:
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# Name: cgpa, dtype: float64

# %%
y=df['package']
y.head()
# Out:
# 0    3.26
# 1    1.98
# 2    3.25
# 3    3.67
# 4    3.57
# Name: package, dtype: float64

# %%
plt.boxplot(df['cgpa'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2769725cbd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2769721ebd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27697274c50>],
#  'medians': [<matplotlib.lines.Line2D at 0x2769728d150>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2769728dd10>],
#  'means': []}

# %%
plt.boxplot(df['package'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x276972df890>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x276972e9210>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x276972deb50>],
#  'medians': [<matplotlib.lines.Line2D at 0x276972ea7d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x276972eb2d0>],
#  'means': []}

# %%
sns.displot(y,kind='kde')

# %%
# model building
#split our data intpo training
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
x_train=x_train.values.reshape(-1,1)

# %%
x_train.shape
# Out:
# (160, 1)

# %%
#### using linear reression
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test.values.reshape(-1,1))
y_pred
# Out:
# array([2.97012606, 2.55516816, 2.61856451, 3.40237388, 3.05657563,
#        2.35921582, 3.51763996, 2.4687186 , 4.1227869 , 3.21794814,
#        2.12868365, 3.19489493, 2.53787825, 3.05081232, 3.36779405,
#        2.86062328, 2.63009112, 2.82028015, 2.37074243, 2.91825632,
#        3.1660784 , 2.3361626 , 3.50611335, 3.9902309 , 2.20360661,
#        1.90967809, 3.08539215, 2.6070379 , 1.9212047 , 1.90391479,
#        2.91249302, 3.69630239, 2.60127459, 2.09410383, 2.50906173,
#        3.64443265, 3.17184171, 2.97012606, 3.83462169, 2.50329842])

# %%
# R square: Measure of accuracy of the linear regression model
#coefficient of determination
#R square high ===> our model is accurate more

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
#73 percent accurate
# Out:
# 0.7297167943957027

# %%
# to find coefficents of best fit line
w1=lr.coef_
w0=lr.intercept_
print(w1,w0)
# Out:
# [0.57633042] -1.0296070415163094

# %%
pred_pack=0.57633042*9.7+-1.0296070415163094
pred_pack
# Out:
# 4.5607980324836905

# %%
#### x_train y_train
plt.scatter(x_train,y_train)
plt.scatter(x_test,y_test)
plt.plot(x_test,y_pred,color='r')
