# %%
import os 
import pandas as pd 
import numpy as np
import matplotlib as plt
print(os.getcwd())
# Out:
# C:\Users\atharv\hotel booking

# %%
print(os.path.isfile('hotel_bookings.csv'))
# Out:
# True

# %%
# import a csv file in notebook
df=pd.read_csv('hotel_bookings.csv')

# %%
# show all the column
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_month_year',
#        'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time arrival_month_year  arrival_date_year  \
# 0  Resort Hotel            0        342             Jul-15               2015
# 1  Resort Hotel            0        737             Jul-15               2015
# 2  Resort Hotel            0          7             Jul-15               2015
# 3  Resort Hotel            0         13             Jul-15               2015
# 4  Resort Hotel            0         14             Jul-15               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
pd.set_option('display.max_columns',None)
#pd.set_option('display.max_rowss',None)

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time arrival_month_year  arrival_date_year  \
# 0  Resort Hotel            0        342             Jul-15               2015
# 1  Resort Hotel            0        737             Jul-15               2015
# 2  Resort Hotel            0          7             Jul-15               2015
# 3  Resort Hotel            0         13             Jul-15               2015
# 4  Resort Hotel            0         14             Jul-15               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
print(df.shape)
# Out:
# (119390, 33)

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time arrival_month_year  \
# 119385  City Hotel            0         23             Aug-17
# 119386  City Hotel            0        102             Aug-17
# 119387  City Hotel            0         34             Aug-17
# 119388  City Hotel            0        109             Aug-17
# 119389  City Hotel            0        205             Aug-17
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 119385               2017             August                        35
# 119386               2017             August                        35
# 119387               2017             August                        35
# 119388               2017             August                        35
# 119389               2017             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# ...

# %%
print(df['hotel'].unique()) # gives unique values
print(df['hotel'].nunique()) # no of unique values
# Out:
# ['Resort Hotel' 'City Hotel']
# 2

# %%
for i in df.columns:
    print(i,df[i].unique(),df[i].nunique())
    print('*'*100)
# Out:
# hotel ['Resort Hotel' 'City Hotel'] 2
# ****************************************************************************************************
# is_canceled [0 1] 2
# ****************************************************************************************************
# lead_time [342 737   7  13  14   0   9  85  75  23  35  68  18  37  12  72 127  78
#   48  60  77  99 118  95  96  69  45  40  15  36  43  70  16 107  47 113
#   90  50  93  76   3   1  10   5  17  51  71  63  62 101   2  81 368 364
#  324  79  21 109 102   4  98  92  26  73 115  86  52  29  30  33  32   8
#  100  44  80  97  64  39  34  27  82  94 110 111  84  66 104  28 258 112
#   65  67  55  88  54 292  83 105 280 394  24 103 366 249  22  91  11 108
#  106  31  87  41 304 117  59  53  58 116  42 321  38  56  49 317   6  57
#   19  25 315 123  46  89  61 312 299 130  74 298 119  20 286 136 129 124
#  327 131 460 140 114 139 122 137 126 120 128 135 150 143 151 132 125 157
# ...

# %%
#info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_month_year              119390 non-null  object
#  4   arrival_date_year               119390 non-null  int64
#  5   arrival_date_month              119390 non-null  object
#  6   arrival_date_week_number        119390 non-null  int64
#  7   arrival_date_day_of_month       119390 non-null  int64
#  8   stays_in_weekend_nights         119390 non-null  int64
#  9   stays_in_week_nights            119390 non-null  int64
#  10  adults                          119390 non-null  int64
#  11  children                        119386 non-null  float64
# ...

# %%
print((df.isnull().sum()/len(df)*100))
# Out:
# hotel                              0.000000
# is_canceled                        0.000000
# lead_time                          0.000000
# arrival_month_year                 0.000000
# arrival_date_year                  0.000000
# arrival_date_month                 0.000000
# arrival_date_week_number           0.000000
# arrival_date_day_of_month          0.000000
# stays_in_weekend_nights            0.000000
# stays_in_week_nights               0.000000
# adults                             0.000000
# children                           0.003350
# babies                             0.000000
# meal                               0.000000
# country                            0.408744
# market_segment                     0.000000
# distribution_channel               0.000000
# is_repeated_guest                  0.000000
# previous_cancellations             0.000000
# previous_bookings_not_canceled     0.000000
# reserved_room_type                 0.000000
# ...

# %%
df.drop('company',inplace=True,axis=1)

# %%
print((df.isnull().sum()/len(df)*100))
# Out:
# hotel                              0.000000
# is_canceled                        0.000000
# lead_time                          0.000000
# arrival_month_year                 0.000000
# arrival_date_year                  0.000000
# arrival_date_month                 0.000000
# arrival_date_week_number           0.000000
# arrival_date_day_of_month          0.000000
# stays_in_weekend_nights            0.000000
# stays_in_week_nights               0.000000
# adults                             0.000000
# children                           0.003350
# babies                             0.000000
# meal                               0.000000
# country                            0.408744
# market_segment                     0.000000
# distribution_channel               0.000000
# is_repeated_guest                  0.000000
# previous_cancellations             0.000000
# previous_bookings_not_canceled     0.000000
# reserved_room_type                 0.000000
# ...

# %%
df_num=df.select_dtypes(include='number')
df_cat=df.select_dtypes(include='object')

# %%
df_num.columns
# Out:
# Index(['is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_week_number', 'arrival_date_day_of_month',
#        'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children',
#        'babies', 'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'booking_changes', 'agent',
#        'days_in_waiting_list', 'adr', 'required_car_parking_spaces',
#        'total_of_special_requests'],
#       dtype='object')

# %%
df_cat.columns
# Out:
# Index(['hotel', 'arrival_month_year', 'arrival_date_month', 'meal', 'country',
#        'market_segment', 'distribution_channel', 'reserved_room_type',
#        'assigned_room_type', 'deposit_type', 'customer_type',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df_num.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df_cat.describe()
# Out:
#              hotel arrival_month_year arrival_date_month    meal country  \
# count       119390             119390             119390  119390  118902
# unique           2                 26                 12       5     177
# top     City Hotel             May-17             August      BB     PRT
# freq         79330               6313              13877   92310   48590
#
#        market_segment distribution_channel reserved_room_type  \
# count          119390               119390             119390
# unique              8                    5                 10
# top         Online TA                TA/TO                  A
# freq            56477                97870              85994
#
#        assigned_room_type deposit_type customer_type reservation_status  \
# count              119390       119390        119390             119390
# unique                 12            3             4                  3
# ...

# %%
#Excel
#pd.read_excel(sheet_name='dsdsf')

# %%
import matplotlib.pyplot as plt

# %%
df_num['lead_time'].plot(kind='hist')
# plt.hist(df_num['lead_time'])
plt.show()

# %%
columns=3
rows=len(df_num.columns)//3
i=1
plt.figure(figsize=(25,25))
for col in df_num.columns:
    #print(i)
    plt.subplot(rows+1,columns,i)
    plt.hist(df_num[col])
    plt.title(col)
    i=i+1

# %%
columns=3
rows=len(df_num.columns)//3
i=1
plt.figure(figsize=(25,25))
for col in df_num.columns:
    #print(i)
    plt.subplot(rows+1,columns,i)
    df_num[col].plot(kind='hist',figsize=(25,25))
    plt.title(col)
    i=i+1

# %%
# df_num['is_canceled'].plot(kind='pie')
# # plt.hist(df_num['lead_time'])
# plt.show()

# %%
df_cancel=df_num['is_canceled'].value_counts()

# %%
df_cancel
# Out:
# is_canceled
# 0    75166
# 1    44224
# Name: count, dtype: int64

# %%
df_cancel.plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df_year=df_num['arrival_date_year'].value_counts()
df_year
# Out:
# arrival_date_year
# 2016    56707
# 2017    40687
# 2015    21996
# Name: count, dtype: int64

# %%
df_year.plot(kind='bar')
plt.show()

# %%
columns=3
rows=len(df_num.columns)//3
i=1
plt.figure(figsize=(25,25))
for col in df_num.columns:
    #print(i)
    plt.subplot(rows+1,columns,i)
    df_num[col].plot(kind='box',figsize=(25,25))
    plt.title(col)
    i=i+1

# %%
df_rr=df_cat['reserved_room_type'].value_counts()
df_ar=df_cat['assigned_room_type'].value_counts()

# %%
df_rr.sort_index(inplace=True)
df_ar.sort_index(inplace=True)

# %%
df_new=pd.concat([df_ar,df_rr],axis=1)
df_new
# Out:
#    count    count
# A  74053  85994.0
# B   2163   1118.0
# C   2375    932.0
# D  25322  19201.0
# E   7806   6535.0
# F   3751   2897.0
# G   2553   2094.0
# H    712    601.0
# I    363      NaN
# K    279      NaN
# L      1      6.0
# P     12     12.0

# %%
df_new.columns=['Assigned_room','reserved_room']
df_new
# Out:
#    Assigned_room  reserved_room
# A          74053        85994.0
# B           2163         1118.0
# C           2375          932.0
# D          25322        19201.0
# E           7806         6535.0
# F           3751         2897.0
# G           2553         2094.0
# H            712          601.0
# I            363            NaN
# K            279            NaN
# L              1            6.0
# P             12           12.0

# %%
df_new['Assigned_room'].plot(kind='line')
plt.figure(figsize=(10,8))
plt.plot(df_new.index,df_new['Assigned_room'],color='r',marker='o')
